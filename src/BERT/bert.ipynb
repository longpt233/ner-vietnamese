# %%
print("hello")

# %%
import numpy as np

shape = (10,10)
structure = np.ones((3,) * len(shape), dtype=np.int8)

# %%
len(shape)
# Out:
# 2

# %%
structure
# Out:
# array([[1, 1, 1],
#        [1, 1, 1],
#        [1, 1, 1]], dtype=int8)

# %%
arr = np.array([1, 2, 3, 4, 5])

print(arr.shape)
# Out:
# (5,)
